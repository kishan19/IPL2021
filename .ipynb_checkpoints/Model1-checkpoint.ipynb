# %% [markdown]
# #### Steps in this notebook
# - Clean Cricsheet data, create basic model
# - Run basic model for testing

# %%
import pandas as pd
import numpy as np
import math

# %%
cricsheet_df=pd.read_csv('./data/all_matches.csv')
# Out:
# /Users/kishan/Desktop/IPL/.ipl/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
###Load input format dataframe

test_df=pd.read_csv('./submission/inputFile.csv')

test_df

##Venue needs to go through standardizer
## innigns is either 1 or 2
## Batting team and bowling team better to go through standardizer, since KXIP has changed names between seasons
## Batsmen list must be minimum 2 and bowlers list must be minimum 2
## Need to standardize batter and bowlers
## Batting and bowling types of batters and bowlers to be inferred from custom module
# Out:
#                     venue  innings    batting_team           bowling_team  \
# 0  MA Chidambaram Stadium        1  Mumbai Indians  Kolkata Knight Riders
#
#                                            batsmen  \
# 0  Quinton de Kock, Rohit Sharma, Suryakumar Yadav
#
#                                              bowlers
# 0  Harbhajan Singh, Varun Chakravarthy, Shakib Al...

# %% [markdown]
# #### Subsetting the given data
#
# - Remove seasons before 2018
# - Remove super over innings (innings>=3)
# - Remove unnecessary columns

# %%
##no use of other wicket type and other player dismissed columns
assert cricsheet_df.loc[~pd.isnull(cricsheet_df['other_wicket_type'])].shape[0]==0
assert cricsheet_df.loc[~pd.isnull(cricsheet_df['other_player_dismissed'])].shape[0]==0

# %%
cricsheet_df.drop(columns=['other_wicket_type','other_player_dismissed'],axis=1,inplace=True)

# %%
cricsheet_df['start_date']=pd.to_datetime(cricsheet_df['start_date'])

# %%
##Filter from 2018 April 7th
cricsheet_df.loc[cricsheet_df['start_date']>='2018','start_date'].describe(include='all')
# Out:
# <ipython-input-30-ff7ecb1db089>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   cricsheet_df.loc[cricsheet_df['start_date']>='2018','start_date'].describe(include='all')
# count                   43894
# unique                    149
# top       2020-10-18 00:00:00
# freq                      520
# first     2018-04-07 00:00:00
# last      2021-04-11 00:00:00
# Name: start_date, dtype: object

# %%
cdf=cricsheet_df.loc[cricsheet_df['start_date']>='2018'].reset_index(drop=True)

# %% [markdown]
# ### EDA

# %%
##List of all venues in this
set(cdf['venue'])
# Out:
# {'Arun Jaitley Stadium',
#  'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#  'Dubai International Cricket Stadium',
#  'Eden Gardens',
#  'Holkar Cricket Stadium',
#  'M.Chinnaswamy Stadium',
#  'MA Chidambaram Stadium',
#  'MA Chidambaram Stadium, Chepauk, Chennai',
#  'Maharashtra Cricket Association Stadium',
#  'Punjab Cricket Association IS Bindra Stadium',
#  'Rajiv Gandhi International Stadium',
#  'Sawai Mansingh Stadium',
#  'Sharjah Cricket Stadium',
#  'Sheikh Zayed Stadium',
#  'Wankhede Stadium',
#  'Wankhede Stadium, Mumbai'}

# %% [markdown]
# #### There are 231 different IPL players across teams from 2018.

# %%
##List of all unique players in the dataset
ipl_players=cdf.loc[:,['striker','non_striker','bowler']].drop_duplicates().melt()['value'].drop_duplicates().tolist()

len(ipl_players),ipl_players
# Out:
# (231,
#  ['V Kohli',
#   'PA Patel',
#   'MM Ali',
#   'AB de Villiers',
#   'SO Hetmyer',
#   'S Dube',
#   'C de Grandhomme',
#   'NA Saini',
#   'YS Chahal',
#   'UT Yadav',
#   'Mohammed Siraj',
#   'SR Watson',
#   'AT Rayudu',
#   'SK Raina',
#   'KM Jadhav',
#   'RA Jadeja',
#   'DA Warner',
#   'JM Bairstow',
#   'V Shankar',
#   'YK Pathan',
#   'MK Pandey',
#   'CA Lynn',
#   'N Rana',
#   'RV Uthappa',
#   'KD Karthik',
#   'AD Russell',
#   'Shubman Gill',
#   'PP Shaw',
#   'S Dhawan',
#   'SS Iyer',
#   'CA Ingram',
#   'RR Pant',
#   'KMA Paul',
#   'AR Patel',
#   'R Tewatia',
#   'RG Sharma',
#   'Q de Kock',
#   'SA Yadav',
#   'KA Pollard',
#   'Yuvraj Singh',
#   'HH Pandya',
#   'KH Pandya',
#   'BCJ Cutting',
#   'MJ McClenaghan',
#   'Rasikh Salam',
#   'KL Rahul',
#   'MA Agarwal',
#   'CH Gayle',
#   'SN Khan',
#   'N Pooran',
#   'Mandeep Singh',
#   'AM Rahane',
#   'JC Buttler',
#   'SV Samson',
#   'SPD Smith',
#   'RA Tripathi',
#   'BA Stokes',
#   'K Gowtham',
#   'JC Archer',
#   'JD Unadkat',
#   'S Gopal',
#   'DS Kulkarni',
#   'MS Dhoni',
#   'DJ Bravo',
#   'SP Narine',
#   'DA Miller',
#   'M Markande',
#   'JJ Bumrah',
#   'KS Williamson',
#   'Rashid Khan',
#   'NS Naik',
#   'PP Chawla',
#   'Kuldeep Yadav',
#   'GH Vihari',
#   'P Ray Barman',
#   'SM Curran',
#   'GC Viljoen',
#   'R Ashwin',
#   'M Ashwin',
#   'Mohammed Shami',
#   'CH Morris',
#   'HV Patel',
#   'Avesh Khan',
#   'K Rabada',
#   'S Lamichhane',
#   'MP Stoinis',
#   'DL Chahar',
#   'SN Thakur',
#   'MM Sharma',
#   'DJ Hooda',
#   'Mohammad Nabi',
#   'F du Plessis',
#   'Ishan Kishan',
#   'RD Chahar',
#   'B Kumar',
#   'Sandeep Sharma',
#   'S Kaul',
#   'AD Nath',
#   'TG Southee',
#   'P Negi',
#   'M Prasidh Krishna',
#   'HF Gurney',
#   'KK Nair',
#   'SD Lad',
#   'AS Joseph',
#   'R Parag',
#   'MJ Santner',
#   'JL Denly',
#   'CR Brathwaite',
#   'LS Livingstone',
#   'C Munro',
#   'RK Bhui',
#   'Abhishek Sharma',
#   'KK Ahmed',
#   'Mujeeb Ur Rahman',
#   'AJ Turner',
#   'STR Binny',
#   'SW Billings',
#   'E Lewis',
#   'Harbhajan Singh',
#   'MA Wood',
#   'Imran Tahir',
#   'G Gambhir',
#   'DT Christian',
#   'BB McCullum',
#   'CR Woakes',
#   'RK Singh',
#   'R Vinay Kumar',
#   'DJM Short',
#   'B Laughlin',
#   'WP Saha',
#   'TK Curran',
#   'GJ Maxwell',
#   'PJ Sangwan',
#   'Shakib Al Hasan',
#   'B Stanlake',
#   'AJ Finch',
#   'AJ Tye',
#   'Washington Sundar',
#   'A Dananjaya',
#   'JJ Roy',
#   'Shivam Mavi',
#   'MG Johnson',
#   'M Vijay',
#   'S Nadeem',
#   'TA Boult',
#   'CJ Anderson',
#   'H Klaasen',
#   'M Vohra',
#   'BB Sran',
#   'LE Plunkett',
#   'A Mishra',
#   'Basil Thampi',
#   'Mustafizur Rahman',
#   'MK Tiwary',
#   'AS Rajpoot',
#   'AD Hales',
#   'MK Lomror',
#   'JP Duminy',
#   'DR Shorey',
#   'NV Ojha',
#   'P Chopra',
#   'JPR Scantlebury-Searles',
#   'IS Sodhi',
#   'Anureet Singh',
#   'SP Goswami',
#   'Harpreet Brar',
#   'SE Rutherford',
#   'Y Prithvi Raj',
#   'KC Cariappa',
#   'Gurkeerat Singh',
#   'P Simran Singh',
#   'J Suchith',
#   'MJ Guptill',
#   'VR Aaron',
#   'I Sharma',
#   'SS Tiwary',
#   'JL Pattinson',
#   'A Nortje',
#   'CJ Jordan',
#   'D Padikkal',
#   'JR Philippe',
#   'PK Garg',
#   'MR Marsh',
#   'T Natarajan',
#   'YBK Jaiswal',
#   'RD Gaikwad',
#   'EJG Morgan',
#   'PJ Cummins',
#   'DW Steyn',
#   'KL Nagarkoti',
#   'Abdul Samad',
#   'JDS Neesham',
#   'Ravi Bishnoi',
#   'I Udana',
#   'CV Varun',
#   'SS Cottrell',
#   'Arshdeep Singh',
#   'Kartik Tyagi',
#   'N Jagadeesan',
#   'AT Carey',
#   'T Banton',
#   'NM Coulter-Nile',
#   'LH Ferguson',
#   'TU Deshpande',
#   'JO Holder',
#   'Shahbaz Ahmed',
#   'P Dubey',
#   'DR Sams',
#   'M Jansen',
#   'RM Patidar',
#   'KA Jamieson',
#   'KV Sharma',
#   'SL Malinga',
#   'JP Behrendorff',
#   'SC Kuggeleijn',
#   'S Midhun',
#   'K Khejroliya',
#   'L Ngidi',
#   'KM Asif',
#   'DJ Willey',
#   'Ankit Sharma',
#   'CJ Dala',
#   'J Yadav',
#   'O Thomas',
#   'AS Roy',
#   'S Sandeep Warrier',
#   'JR Hazlewood',
#   'A Zampa',
#   'CJ Green',
#   'Monu Kumar'])

# %%
### Format seasons
print(set(cdf['season']))

cdf['season']=cdf['season'].astype('str')
print(set(cdf['season']))
# Out:
# {2018, 2019, '2019', '2018', '2020/21', '2021'}
# {'2020/21', '2018', '2019', '2021'}

# %%
##Remove super overs and repeated super over instance from MI KXIP
cdf=cdf.loc[cdf['innings']<=2]

# %%
##Which venues need tweaking? For purposes of training
cdf['venue'].value_counts(ascending=False)
# Out:
# Dubai International Cricket Stadium                    6338
# Sheikh Zayed Stadium                                   5294
# Wankhede Stadium                                       3902
# Eden Gardens                                           3802
# Rajiv Gandhi International Stadium                     3609
# Arun Jaitley Stadium                                   3344
# Sawai Mansingh Stadium                                 3286
# M.Chinnaswamy Stadium                                  3246
# Sharjah Cricket Stadium                                2878
# Punjab Cricket Association IS Bindra Stadium           2429
# MA Chidambaram Stadium                                 2130
# Maharashtra Cricket Association Stadium                1467
# Holkar Cricket Stadium                                  873
# MA Chidambaram Stadium, Chepauk, Chennai                498
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     491
# Wankhede Stadium, Mumbai                                239
# Name: venue, dtype: int64

# %%
cdf.loc[cdf['venue']=='MA Chidambaram Stadium, Chepauk, Chennai','venue']='MA Chidambaram Stadium'
cdf.loc[cdf['venue']=='Wankhede Stadium, Mumbai','venue']='Wankhede Stadium'

# %%
cdf['venue'].value_counts(ascending=False)
# Out:
# Dubai International Cricket Stadium                    6338
# Sheikh Zayed Stadium                                   5294
# Wankhede Stadium                                       4141
# Eden Gardens                                           3802
# Rajiv Gandhi International Stadium                     3609
# Arun Jaitley Stadium                                   3344
# Sawai Mansingh Stadium                                 3286
# M.Chinnaswamy Stadium                                  3246
# Sharjah Cricket Stadium                                2878
# MA Chidambaram Stadium                                 2628
# Punjab Cricket Association IS Bindra Stadium           2429
# Maharashtra Cricket Association Stadium                1467
# Holkar Cricket Stadium                                  873
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     491
# Name: venue, dtype: int64

# %%
##List of all unique teams in the dataset
ipl_teams=cdf.loc[:,['batting_team','bowling_team']].drop_duplicates().melt()['value'].drop_duplicates().tolist()
ipl_teams
##Change Delhi Daredevils to Delhi Capitals
##Change Kings XI Punjab to Punjab Kings
# Out:
# ['Royal Challengers Bangalore',
#  'Chennai Super Kings',
#  'Sunrisers Hyderabad',
#  'Kolkata Knight Riders',
#  'Delhi Capitals',
#  'Mumbai Indians',
#  'Kings XI Punjab',
#  'Rajasthan Royals',
#  'Delhi Daredevils']

# %%
cdf.loc[cdf['batting_team']=='Delhi Daredevils','batting_team']='Delhi Capitals'
cdf.loc[cdf['bowling_team']=='Delhi Daredevils','bowling_team']='Delhi Capitals'
cdf.loc[cdf['batting_team']=='Kings XI Punjab','batting_team']='Punjab Kings'
cdf.loc[cdf['bowling_team']=='Kings XI Punjab','bowling_team']='Punjab Kings'

# %%
##Changed teams list

cdf.loc[:,['batting_team','bowling_team']].drop_duplicates().melt()['value'].drop_duplicates().tolist()
# Out:
# ['Royal Challengers Bangalore',
#  'Chennai Super Kings',
#  'Sunrisers Hyderabad',
#  'Kolkata Knight Riders',
#  'Delhi Capitals',
#  'Mumbai Indians',
#  'Punjab Kings',
#  'Rajasthan Royals']

# %%
##Extras column has captured type of extras
##At test time we will not have ball by ball information, do we need to hold a split of extras in that case??
cdf.drop(columns=['wides','noballs','byes','legbyes','penalty'],inplace=True)

# %% [markdown]
# ### Derive new features

# %%
cdf['total_runs']=cdf['runs_off_bat']+cdf['extras']

# %%
##Get over number
cdf['over_number']=cdf['ball'].apply(lambda x:int(math.ceil(x)))

# %%
def phase_cat(over_number):
    '''Determine phase'''
    if over_number<=6:
        phase="PowerPlay"
    if (over_number>6) & (over_number<=15):
        phase="Middle overs"
    if over_number>15:
        phase="Death overs"
    return phase

# %%
cdf['phase']=cdf['over_number'].apply(phase_cat)

# %%
cdf.to_csv('./data/cleaned_cricsheet.csv',index=False)

# %%
cdf.to_excel('./data/cleaned_cricsheet.xlsx',index=False)

# %% [markdown]
# ### What features can we derive at test time
#
#
# **Assuming that we can add data to lookup in the submission file**
#
# #### Toss related factors
# - Derive who is batting 1st and who is batting 2nd (by order of rows)
# - Check team wise
# - We will know what kind of game it is, if it is a DAY start or NIGHT start, so we can supply that manually into the submission code
#
#
# #### Venue related factors
# - Venue specific stats, avg PP score in last 'n' games batting 1st (through a lookup table)
# - Venue specific stats, avg PP score in last 'n' games batting 2nd (through a lookup table)
#
# #### Team related factors
#
# - When team is batting 1st, what is the avg PP score
# - When team is batting 2nd, what is the avg PP score
#
#
# #### Batsman related factors
#
# - Since the input is a set of all batters in the list, the order will matter. Assuming openers are 1st two, we can measure size of this set to determine number of wickets that have fallen
#
# - We will not have split of how many balls each batter faced. Hence we need to be careful not to over use the batsman feature
#
# - Lookup batter at venue in 1st innings
#
# - Lookup batter at venue in 2nd innings
#
# - One proxy could be to determine average batting time of batsman in PP by batting position at venue
#
# #### Bowler related factors
#
# - Again we dont have info on the split of balls bowled.
#
# - Lookup bowler at venue in 1st innings how many overs he has generally bowled * ER
#
# - Lookup bowler at venue in 2nd innings how many overs he has generally bowled * ER at venue
#
# #### Batsman-Bowler matchups
#
# - Infer batting hand of Batsman, bowling type of bowlers
#
# #### Handle unknowns
#
# - Bowlers like Chetan Sakariya, Avesh Khan are bowling rarely or for the first time. Model must be robust enough to handle "Unknowns"

# %% [markdown]
# ### Begin model training pipeline

# %%
game_start_type="Night"

# %%
##Venue related sums
venue_df=cdf.loc[cdf['phase']=='PowerPlay'].groupby(['venue','start_date','match_id','innings'])['total_runs','wicket_type'].agg({'total_runs':'sum','wicket_type':'count'}).reset_index()
# Out:
# <ipython-input-225-e63dc6b94306>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   venue_df=cdf.loc[cdf['phase']=='PowerPlay'].groupby(['venue','start_date','match_id','innings'])['total_runs','wicket_type'].agg({'total_runs':'sum','wicket_type':'count'}).reset_index()

# %%
venue_df.to_excel('./data/venue_df.xlsx',index=False)

# %% [markdown]
# ### Powerplay specific features for 2018, 2019. Try to use it on 2021

# %%
match_df=cdf.loc[cdf['match_id']==1136565]

# %%
match_df
# Out:
#       match_id season start_date                   venue  innings  ball  \
# 8950   1136565   2018 2018-04-10  MA Chidambaram Stadium        1   0.1
# 8951   1136565   2018 2018-04-10  MA Chidambaram Stadium        1   0.2
# 8952   1136565   2018 2018-04-10  MA Chidambaram Stadium        1   0.3
# 8953   1136565   2018 2018-04-10  MA Chidambaram Stadium        1   0.4
# 8954   1136565   2018 2018-04-10  MA Chidambaram Stadium        1   0.5
# ...        ...    ...        ...                     ...      ...   ...
# 9191   1136565   2018 2018-04-10  MA Chidambaram Stadium        2  19.3
# 9192   1136565   2018 2018-04-10  MA Chidambaram Stadium        2  19.4
# 9193   1136565   2018 2018-04-10  MA Chidambaram Stadium        2  19.5
# 9194   1136565   2018 2018-04-10  MA Chidambaram Stadium        2  19.6
# 9195   1136565   2018 2018-04-10  MA Chidambaram Stadium        2  19.7
#
#                batting_team           bowling_team    striker non_striker  \
# 8950  Kolkata Knight Riders    Chennai Super Kings    CA Lynn   SP Narine
# 8951  Kolkata Knight Riders    Chennai Super Kings    CA Lynn   SP Narine
# 8952  Kolkata Knight Riders    Chennai Super Kings    CA Lynn   SP Narine
# 8953  Kolkata Knight Riders    Chennai Super Kings  SP Narine     CA Lynn
# 8954  Kolkata Knight Riders    Chennai Super Kings  SP Narine     CA Lynn
# ...                     ...                    ...        ...         ...
# 9191    Chennai Super Kings  Kolkata Knight Riders   DJ Bravo   RA Jadeja
# 9192    Chennai Super Kings  Kolkata Knight Riders  RA Jadeja    DJ Bravo
# 9193    Chennai Super Kings  Kolkata Knight Riders  RA Jadeja    DJ Bravo
# 9194    Chennai Super Kings  Kolkata Knight Riders   DJ Bravo   RA Jadeja
# 9195    Chennai Super Kings  Kolkata Knight Riders  RA Jadeja    DJ Bravo
#
#              bowler  runs_off_bat  extras wicket_type player_dismissed  \
# 8950      DL Chahar             0       0         NaN              NaN
# 8951      DL Chahar             4       0         NaN              NaN
# 8952      DL Chahar             1       0         NaN              NaN
# 8953      DL Chahar             0       1         NaN              NaN
# 8954      DL Chahar             0       0         NaN              NaN
# ...             ...           ...     ...         ...              ...
# 9191  R Vinay Kumar             1       0         NaN              NaN
# 9192  R Vinay Kumar             0       1         NaN              NaN
# 9193  R Vinay Kumar             1       0         NaN              NaN
# 9194  R Vinay Kumar             1       0         NaN              NaN
# 9195  R Vinay Kumar             6       0         NaN              NaN
#
#       total_runs  over_number        phase
# 8950           0            1    PowerPlay
# 8951           4            1    PowerPlay
# 8952           1            1    PowerPlay
# 8953           1            1    PowerPlay
# 8954           0            1    PowerPlay
# ...          ...          ...          ...
# 9191           1           20  Death overs
# 9192           1           20  Death overs
# 9193           1           20  Death overs
# 9194           1           20  Death overs
# 9195           6           20  Death overs
#
# [246 rows x 18 columns]

# %%
pp_score1=int(match_df.loc[(match_df['phase']=='PowerPlay')&(match_df['innings']==1)]['total_runs'].sum())
pp_score2=int(match_df.loc[(match_df['phase']=='PowerPlay')&(match_df['innings']==2)]['total_runs'].sum())

# %%
pp_batters1=match_df.loc[(match_df['phase']=='PowerPlay')&(match_df['innings']==1),['striker','non_striker']].melt()['value'].drop_duplicates().tolist()
pp_batters1.sort()
pp_batters2=match_df.loc[(match_df['phase']=='PowerPlay')&(match_df['innings']==2),['striker','non_striker']].melt()['value'].drop_duplicates().tolist()
pp_batters2.sort()

# %%
pp_batters1, pp_batters2
# Out:
# (['AB de Villiers', 'MM Ali', 'PA Patel', 'V Kohli'],
#  ['AT Rayudu', 'SK Raina', 'SR Watson'])

# %%
pp_bowlers1=match_df.loc[(match_df['phase']=='PowerPlay')&(match_df['innings']==1),['bowler']].melt()['value'].drop_duplicates().tolist()
pp_bowlers1.sort()


pp_bowlers2=match_df.loc[(match_df['phase']=='PowerPlay')&(match_df['innings']==2),['bowler']].melt()['value'].drop_duplicates().tolist()
pp_bowlers2.sort()

# %%
pp_bowlers1,pp_bowlers2
# Out:
# (['DL Chahar', 'Harbhajan Singh'], ['MM Ali', 'NA Saini', 'YS Chahal'])

# %%
match_df
# Out:
#      match_id season start_date                   venue  innings  ball  \
# 0     1175356   2019 2019-03-23  MA Chidambaram Stadium        1   0.1
# 1     1175356   2019 2019-03-23  MA Chidambaram Stadium        1   0.2
# 2     1175356   2019 2019-03-23  MA Chidambaram Stadium        1   0.3
# 3     1175356   2019 2019-03-23  MA Chidambaram Stadium        1   0.4
# 4     1175356   2019 2019-03-23  MA Chidambaram Stadium        1   0.5
# ..        ...    ...        ...                     ...      ...   ...
# 209   1175356   2019 2019-03-23  MA Chidambaram Stadium        2  17.1
# 210   1175356   2019 2019-03-23  MA Chidambaram Stadium        2  17.2
# 211   1175356   2019 2019-03-23  MA Chidambaram Stadium        2  17.3
# 212   1175356   2019 2019-03-23  MA Chidambaram Stadium        2  17.4
# 213   1175356   2019 2019-03-23  MA Chidambaram Stadium        2  17.5
#
#                     batting_team                 bowling_team    striker  \
# 0    Royal Challengers Bangalore          Chennai Super Kings    V Kohli
# 1    Royal Challengers Bangalore          Chennai Super Kings   PA Patel
# 2    Royal Challengers Bangalore          Chennai Super Kings   PA Patel
# 3    Royal Challengers Bangalore          Chennai Super Kings   PA Patel
# 4    Royal Challengers Bangalore          Chennai Super Kings   PA Patel
# ..                           ...                          ...        ...
# 209          Chennai Super Kings  Royal Challengers Bangalore  KM Jadhav
# 210          Chennai Super Kings  Royal Challengers Bangalore  RA Jadeja
# 211          Chennai Super Kings  Royal Challengers Bangalore  RA Jadeja
# 212          Chennai Super Kings  Royal Challengers Bangalore  RA Jadeja
# 213          Chennai Super Kings  Royal Challengers Bangalore  RA Jadeja
#
#     non_striker     bowler  runs_off_bat  extras wicket_type player_dismissed  \
# 0      PA Patel  DL Chahar             1       0         NaN              NaN
# 1       V Kohli  DL Chahar             0       0         NaN              NaN
# 2       V Kohli  DL Chahar             0       0         NaN              NaN
# 3       V Kohli  DL Chahar             0       0         NaN              NaN
# 4       V Kohli  DL Chahar             4       0         NaN              NaN
# ..          ...        ...           ...     ...         ...              ...
# 209   RA Jadeja     S Dube             1       0         NaN              NaN
# 210   KM Jadhav     S Dube             0       1         NaN              NaN
# 211   KM Jadhav     S Dube             0       0         NaN              NaN
# 212   KM Jadhav     S Dube             0       0         NaN              NaN
# 213   KM Jadhav     S Dube             1       0         NaN              NaN
#
#      total_runs  over_number        phase
# 0             1            1    PowerPlay
# 1             0            1    PowerPlay
# 2             0            1    PowerPlay
# 3             0            1    PowerPlay
# 4             4            1    PowerPlay
# ..          ...          ...          ...
# 209           1           18  Death overs
# 210           1           18  Death overs
# 211           0           18  Death overs
# 212           0           18  Death overs
# 213           1           18  Death overs
#
# [214 rows x 18 columns]
